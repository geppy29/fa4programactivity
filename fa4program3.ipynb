# %% [markdown]
# <a href="https://colab.research.google.com/github/geppy29/fa4programactivity/blob/main/fa4program3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for number in range(1, 11):
    if number == 4:
        continue

    if number == 6:
        pass

    if number == 8:
        break

    print(number)
