# %% [markdown]
# <a href="https://colab.research.google.com/github/geppy29/fa4programactivity/blob/main/fa4program1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for number in range(1, 21):
    if number % 2 == 0:
        continue

    print(number)
