# %% [markdown]
# <a href="https://colab.research.google.com/github/geppy29/fa4programactivity/blob/main/fa4program2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
while True:
    user_input = input("Enter the password: ")

    if user_input == secret_password:
        print("Access Granted!")
        break  # This exits the loop immediately

    print("Incorrect password. Please try again.")
